# %% [markdown]
# # Some Interesting modules  to play with in Python :
#     '''
#     1) pyperclip
#     2) emojis
#     3) emoji -> emojize
#     4) howdoi
#     5) wikipedia
#     6) New types at runtime(dynamically)
#     7) sys.exit()
#     8) urllib
#     9) Turtle
#
#     '''

# %% [markdown]
# ##  1) pyperclip module
#
# 💨 This module was created to enable cross-platform copy-pasting in Python which was earlier absent.<br>
# 💨 The pyperclip module has copy() and paste() functions that can send text to and receive text from   your computer’s &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;clipboard. <br>
# 💨 Sending the output of your program to the clipboard will make it easy to paste it on an email,       word processor, or some &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;other software.

# %%
# This will import pyperclip

import pyperclip
pyperclip.copy("Hello world !")
pyperclip.paste()
  
pyperclip.copy("Isn't pyperclip interesting?")
pyperclip.paste()
# Out:
# "Isn't pyperclip interesting?"

# %% [markdown]
# ## 2) emojis

# %%
import emojis
emojified = emojis.encode("There is a :snake: in my boot !")
print(emojified)

# https://www.webfx.com/tools/emoji-cheat-sheet/
# Out:
# There is a 🐍 in my boot !

# %% [markdown]
# ## 3) emoji

# %%
# emoji 

from emoji import emojize
print("\U0001F600")

'''
From the list of unicodes, replace “+” with “000”. For example – “U+1F600” will become
“U0001F600” and prefix the unicode with “\” and print it.

'''
# http://www.unicode.org/emoji/charts/full-emoji-list.html#1f600

print("\U0001F44C")
# Out:
# 😀
# 👌

# %% [markdown]
# ## 4)  howdoi
#
# ✅ Ask whatever question you have and it will try it’s best to answer it.

# %%
from howdoi import howdoi

query = "create a python list"
print( howdoi.howdoi(query))
# Out:
# >>> from timeit import timeit
# >>>
# >>> # Test 1
# >>> test = """
# ... my_list = []
# ... for i in xrange(50):
# ...     my_list.append(0)
# ... """
# >>> timeit(test)
# 22.384258893239178
# >>>
# >>> # Test 2
# >>> test = """
# ... my_list = []
# ... for i in xrange(50):
# ...     my_list += [0]
# ... """
# >>> timeit(test)
# 34.494779364416445
# >>>
# >>> # Test 3
# >>> test = "my_list = [0 for i in xrange(50)]"
# >>> timeit(test)
# 9.490926919482774
# >>>
# >>> # Test 4
# >>> test = "my_list = [0] * 50"
# >>> timeit(test)
# 1.5340533503559755
# >>>

# %% [markdown]
# ## 5) wikipedia
#
# 🥖 As if howdoi wasn’t enough, we can now import the entire Wikipedia!<br>
# 🥖 Yes, We can now import Wikipedia in Python using Wikipedia module. Use the incessant flow of       knowledge with Python for &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;daily needs.

# %%
import wikipedia
result = wikipedia.page("Chess")
print(result.summary)
# Out:
# Chess is a recreational and competitive board game played between two players. It is sometimes called Western or international chess to distinguish it from related games such as xiangqi. The current form of the game emerged in Southern Europe during the second half of the 15th century after evolving from similar, much older games of Indian and Persian origin. Today, chess is one of the world's most popular games, played by millions of people worldwide at home, in clubs, online, by correspondence, and in tournaments.
# ...

# %% [markdown]
# ### If you wish to get a particular number of sentences from the summary, just pass that as an argument to the summary() function:

# %%
import wikipedia
print(wikipedia.summary("Chess", sentences = 2))
# Out:
# Chess is a recreational and competitive board game played between two players. It is sometimes called Western or international chess to distinguish it from related games such as xiangqi.

# %% [markdown]
# ## 6) New types at runtime(dynamically)
#
# 📏 This can create new types in a fully dynamic way. It’s the same as creating a class but something new !

# %%
# Python program to create new type object
  
# Creates a new type object
NewType = type("NewType", (object, ), {"attr": "hello newtype"})
New = NewType()
  
# Print the type of object
print(type(New))
  
# Print the attribute of object
print(New.attr)
# Out:
# <class '__main__.NewType'>
# hello newtype

# %%
# OR

# Creates a class
class NewType:
    attr = "hello newtype"
    
# Initialize an object
New = NewType()
  
# Print the type of object
print(type(New))
  
# Print the attribute of object
print(New.attr)
# Out:
# <class '__main__.NewType'>
# hello newtype

# %% [markdown]
# ## 7) sys.exit()
#
# We can cause the program to terminate by calling the sys.exit() function. Since this function is in the sys module, firstly, the sys module should be imported.

# %%
# sys.exit()

# Cause the program to terminate by calling the sys.exit() function.

# This will import sys module
import sys
  
while True:
    print("Type 'exit' to exit")
    response = input()
    if response.lower() == "exit":
        print("Exiting the program")
        sys.exit()
    print("You typed", response)
# Out:
# Type 'exit' to exit
# Apple
# You typed Apple
# Type 'exit' to exit
# exit
# Exiting the program
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# ## 8) urllib
#
# 💨 Urllib module is the URL handling module for python. It is used to fetch URLs (Uniform Resource Locators). It uses the &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;urlopen function and is able to fetch URLs using a variety of different protocols.
#
# 💨 Urllib is a package that collects several modules for working with URLs, such as:
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;◾ urllib.request for opening and reading.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;◾ urllib.parse for parsing URLs<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;◾ urllib.error for the exceptions raised<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;◾ urllib.robotparser for parsing robot.txt files

# %%
# This will import urlopen class from urllib module

from urllib.request import urlopen

page = urlopen("https://www.amazon.in/")
print(page.headers)
# Out:
# Server: Server
# Content-Type: text/html;charset=UTF-8
# x-amz-rid: B5WGSZDSE4VNC9XPWA25
# Accept-CH-Lifetime: 86400
# Pragma: no-cache
# Accept-CH: ect,rtt,downlink
# X-Content-Type-Options: nosniff
# X-XSS-Protection: 1;
# Expires: -1
# Cache-Control: no-cache
# Content-Language: en-IN
# X-UA-Compatible: IE=edge
# Strict-Transport-Security: max-age=47474747; includeSubDomains; preload
# Cache-Control: no-transform
# X-Frame-Options: SAMEORIGIN
# Permissions-Policy: interest-cohort=()
# Vary: Accept-Encoding
# Date: Thu, 15 Jul 2021 03:15:26 GMT
# Transfer-Encoding: chunked
# Connection: close
# Connection: Transfer-Encoding

# %% [markdown]
# ### You can also see the coding of the website by using read() function

# %%
# This will import urlopen class from urllib module
  
from urllib.request import urlopen
page=urlopen("https://www.amazon.in/")
  
# Fetches the code of the web page

content = page.read()
  
print(content)
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41SIz69qHYL.css,31qGOnSAToL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11bGSgD5pDL.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,21N4kUH7pxL.css,01oDR3IULNL.css,41-PwE7+H0L.css,21j0IlW7xKL.css,01XPHJk60-L.css,014OeDQisGL.css,21aPhFy+riL.css,11gneA3MtJL.css,21fecG8pUzL.css,01RddH8vm-L.css,01CFUgsA
# ...

# %% [markdown]
# ## 9) Turtle
#
# ✔ Turtle is a Python module to draw. <br>
# ✔ It has a huge application and a number of methods which you can learn about in [here](https://docs.python.org/2/library/turtle.html)!. <br>
# ✔ But with just a few basics, pretty cool stuff can be done.

# %%
# Turtle

# This will import turtle module
import turtle
  
myTurtle = turtle.Turtle()
myWin = turtle.Screen()
  
# Turtle to draw a spiral
def drawSpiral(myTurtle, linelen):
    myTurtle.forward(linelen)
    myTurtle.right(90)
    drawSpiral(myTurtle, linelen-10)
    
drawSpiral(myTurtle, 80)
myWin.exitonclick()

# %% [markdown]
# <a><img src="https://i.ibb.co/Kzr5Pfs/sp1.jpg" height="200" /></a>
